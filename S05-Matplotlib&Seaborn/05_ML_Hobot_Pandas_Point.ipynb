# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Y-EIpLOigI9ycCOZRrRSFzAfuN9cxhqT" alt="Hobot Academy" width="300" height="300">
#
# <h1 align="center"><font size="14">Hands-On Machine Learning</font></h1>
# <h3 align="center"><font size="7">Session05: Pandas | Point</font></h3>
# <h3 align="center">Zahra Amini</h3>

# %%
import pandas as pd

# %%
df = pd.read_csv("imdb_top_250_series_global_ratings.csv")

# %%
df_new = df[['Title','Rating','Rating Count']]

# %%
df_new = df_new[df_new['Rating'] == 9 ]

# %%
df_new[df_new['Rating Count'] > '100000']#.nunique()
# Out:
#                                  Title  Rating Rating Count
# 16                      The Last Dance     9.0      118,827
# 17                                Life     9.0       40,832
# 18                            Sherlock     9.0      910,868
# 19                   The Twilight Zone     9.0       82,522
# 20                     The Vietnam War     9.0       24,523
# 21         Batman: The Animated Series     9.0      102,514
# 22  Scam 1992: The Harshad Mehta Story     9.0      142,151

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 16 to 22
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         7 non-null      object
#  1   Rating        7 non-null      float64
#  2   Rating Count  7 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df_new['Rating Count'] = df_new['Rating Count'].apply(lambda x: x.replace(',',''))

# %%
df_new['Rating Count']
# Out:
# 16    118827
# 17     40832
# 18    910868
# 19     82522
# 20     24523
# 21    102514
# 22    142151
# Name: Rating Count, dtype: object

# %%
df_new['Rating Count'] = df_new['Rating Count'].apply(lambda x: int(x))

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 16 to 22
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         7 non-null      object
#  1   Rating        7 non-null      float64
#  2   Rating Count  7 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 224.0+ bytes

# %%
df_new[df_new['Rating Count'] > 100000].nunique()
# Out:
# Title           4
# Rating          1
# Rating Count    4
# dtype: int64
