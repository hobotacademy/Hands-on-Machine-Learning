# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Y-EIpLOigI9ycCOZRrRSFzAfuN9cxhqT" alt="Hobot Academy" width="300" height="300">
#
# <h1 align="center"><font size="14">Hands-On Machine Learning</font></h1>
# <h3 align="center"><font size="7">Session04: Numpy | Part02</font></h3>
# <h3 align="center">Zahra Amini</h3>

# %%
# pip install pip --upgrade

# %%
# pip install numpy

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.21.5

# %%
# import numpy as np
# import math

# %%
# Arrays
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %% [markdown]
# # 🟣 normal distribution
# numpy.random.normal

# %%
import matplotlib.pyplot as plt
from numpy import random
import seaborn as sns

# %% [markdown]
# ### Coins Example

# %%
x = np.array([0,1, 1, 1, 2, 2, 2, 3])

# %%
sns.countplot(x)
# Out:
# C:\Users\amini\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
n_bins = 4
# plt.figure(figsize=(10, 10))
plt.hist(x, n_bins, density = True, histtype ='bar')

plt.show()

# %%
mu, sigma = 0, 0.1
x = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(x, 30, density=True)
plt.show()

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)


count, bins, ignored = plt.hist(s, 30, density=True)

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')

plt.show()

# %%
# mu, sigma = 3, 1
# x = np.random.normal(mu, sigma, 300)
# plt.scatter(x[:150], x[150:])
# plt.show()

# %%
mean = (0, 3)
cov = [[1, 0], [0, 1]]
#x = np.random.multivariate_normal(mean, cov, (3, 3))

# %%
pts = np.random.multivariate_normal(mean, cov, size=800)

# %%
import matplotlib.pyplot as plt
plt.plot(pts[:, 0], pts[:, 1], '.', alpha=0.5)
plt.axis('equal')
plt.grid()
plt.show()

# %%
mean = (0, 3)
cov = [[1, 0], [0, 6]]
x = np.random.multivariate_normal(mean, cov, (3, 3))

# %%
pts = np.random.multivariate_normal(mean, cov, size=800)

# %%
import matplotlib.pyplot as plt
plt.plot(pts[:, 0], pts[:, 1], '.', alpha=0.5)
plt.axis('equal')
plt.grid()
plt.show()

# %% [markdown]
# # Iris dataset Normal?

# %%
def answer_one(): 
    import numpy as np
    import pandas as pd
    from sklearn.datasets import load_iris 
    Iris = load_iris()     
    data = np.c_[Iris.data, Iris.target]
    columns = np.append(Iris.feature_names, ["target"])
    return pd.DataFrame(data, columns=columns)

df = answer_one()

# %%
x1 = df.iloc[:, 1]
x2 = df.iloc[:, 2]
x3 = df.iloc[:, 3]

# %%
sns.distplot(x1, hist=True)
# Out:
# C:\Users\amini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal width (cm)', ylabel='Density'>

# %%
sns.distplot(x2, hist=True)
# Out:
# C:\Users\amini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal length (cm)', ylabel='Density'>

# %%
sns.distplot(x3, hist=True)
# Out:
# C:\Users\amini\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal width (cm)', ylabel='Density'>

# %% [markdown]
# # Finished!
