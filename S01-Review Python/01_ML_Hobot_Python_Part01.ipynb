# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Y-EIpLOigI9ycCOZRrRSFzAfuN9cxhqT" alt="Hobot Academy" width="300" height="300">
#
# <h1 align="center"><font size="14">Hands-On Machine Learning</font></h1>
# <h3 align="center"><font size="7">Session01: Python | Part01</font></h3>
# <h3 align="center">Zahra Amini</h3>

# %% [markdown]
# # 🟣 Variables

# %%
2
# Out:
# 2

# %%
x1 = 2

# %%
x1
# Out:
# 2

# %%
x2 = 2.5
x2
# Out:
# 2.5

# %%
x = -3.2
x
# Out:
# -3.2

# %%
x3 = 100
x3
# Out:
# 100

# %%
x3 = 105
x3
# Out:
# 105

# %%
x4 = 0
x5 = 24

# %%
x4
# Out:
# 0

# %%
x5
# Out:
# 24

# %%
x5 = x4

# %%
x5
# Out:
# 0

# %%
5x = 9
# Out:
#   Cell In[13], line 1
#     5x = 9
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # 🟣 Operators

# %% [markdown]
# ### Addition      ➕

# %%
a = 3
b = 8

# %%
a + b
# Out:
# 11

# %% [markdown]
# ### Subtraction      ➖

# %%
a - b
# Out:
# -5

# %%
b-a
# Out:
# 5

# %% [markdown]
# ### Division      ➗

# %%
a = 5
b = 2

# %%
a / b
# Out:
# 2.5

# %% [markdown]
# ### Modulus %

# %%
a % b
# Out:
# 1

# %% [markdown]
# ### Floor division //

# %%
a // b
# Out:
# 2

# %% [markdown]
# ### Multiplication   *

# %%
a * b
# Out:
# 10

# %% [markdown]
# ### Power      **

# %%
3 ** 2
# Out:
# 9

# %%
a ** b
# Out:
# 25

# %% [markdown]
# #### Operator, print Function

# %%
print("zarb: ", a * b)

a + b
# Out:
# zarb:  10
# 7

# %%
c = a-b
c
# Out:
# 3

# %% [markdown]
# # EX: Compute Perimeter and Area

# %%
x = 3

P = 4 * x

A = x ** 2

print("mohit: ", P, "\n\nmasahat: ", A)
# Out:
# mohit:  12
#
# masahat:  9

# %% [markdown]
# # Perimeter: <a href="https://imgbb.com/"><img src="https://i.ibb.co/vJ4kBfd/Circle1.jpg" alt="Circle1" border="0"></a>
# # Area: <a href="https://ibb.co/7SYJw3Z"><img src="https://i.ibb.co/WHxWbrM/Circle2.jpg" alt="Circle2" border="0"></a>

# %%
r = 3

pi = 3.14

s = pi * r**2

c = 2 * pi * r

# %%
print("Area is: ", s, "\nPerimeter is: ", c)
# Out:
# Area is:  28.26
# Perimeter is:  18.84

# %% [markdown]
# ### Precedence:
#
# <h4><br>Parentheses
# <br>⬇
# <br>Power
# <br>⬇
# <br>Multiplication
# <br>⬇
# <br>Addition
# <br>⬇
# <br>Left to Right</h4>

# %%
1 + 2**3 /4 *5
# Out:
# 11.0

# %%
2**3**2
# Out:
# 512

# %%
2**3
# Out:
# 8

# %%
8**2
# Out:
# 64

# %%
2**9
# Out:
# 512

# %% [markdown]
# # 🟣 type()

# %% [markdown]
# ### Number

# %%
a = 5
b = 2.5

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %% [markdown]
# ### String

# %%
s = 'Hobot'

# %%
type(s)
# Out:
# str

# %%
s * 2
# Out:
# 'HobotHobot'

# %%
x = '123'

# %%
x
# Out:
# '123'

# %%
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 123

# %%
x2 = int(x)

# %%
type(x2)
# Out:
# int

# %%
x + x
# Out:
# '123123'

# %%
s + x
# Out:
# 'Hobot123'

# %% [markdown]
# # 🟣 User Input

# %%
name = input('What is your name?')

# %%
name
# Out:
# ''

# %% [markdown]
# # Comprision Operators
#
#
# ### <, <=
# ### >, >=
# ### ==
# ### !=

# %%
a = 5

b = 12

c = 5

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a == 6
# Out:
# False

# %%
a == c
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a != c
# Out:
# False

# %%
a != 13
# Out:
# True

# %% [markdown]
# # 🟣 IF

# %%
a = -6

# %%
if (a >= 0):
    print('postive')

# %% [markdown]
# # Finished!
